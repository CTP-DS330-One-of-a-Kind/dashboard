# %%
import streamlit as st
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data/MW.csv", encoding='cp1252')

df_state = pd.read_csv("data/state.csv", encoding="unicode_escape")

df.head(5)
# Out:
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# 1                    2.10                                15.61         34.8
# 2                    1.15                                 8.55         34.8
# 3                    1.15                                 8.55         34.8
# 4                    1.65                                12.26         34.8
#
#   Department.Of.Labor.Uncleaned.Data  Department.Of.Labor.Cleaned.Low.Value  \
# 0                                ...                                0.00000
# 1                                2.1                                2.10000
# 2                18.72 - 26.40/wk(b)                                0.46800
# 3                        1.25/day(b)                                0.15625
# 4                            1.65(b)                                1.65000
#
#    Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  \
# 0                                               0.00
# 1                                              15.61
# 2                                               3.48
# 3                                               1.16
# 4                                              12.26
#
#    Department.Of.Labor.Cleaned.High.Value  \
# 0                                 0.00000
# 1                                 2.10000
# 2                                 0.66000
# 3                                 0.15625
# 4                                 1.65000
#
#    Department.Of.Labor.Cleaned.High.Value.2020.Dollars Footnote
# 0                                               0.00        NaN
# 1                                              15.61        NaN
# 2                                               4.91        (b)
# 3                                               1.16        (b)
# 4                                              12.26        (b)

# %%
df['State'] = df['State'].str.lower()

df.columns = df.columns.str.lower()

merged_df = pd.merge(df,df_state[['state','year','governor']])

# %%
# Out:
#    year        state  state.minimum.wage  state.minimum.wage.2020.dollars  \
# 0  1980      alabama                0.00                             0.00
# 1  1980       alaska                3.60                            11.30
# 2  1980      arizona                0.00                             0.00
# 3  1980     arkansas                2.55                             8.00
# 4  1980   california                2.90                             9.10
# 5  1980     colorado                1.90                             5.96
# 6  1980  connecticut                3.12                             9.79
# 7  1980  connecticut                3.12                             9.79
# 8  1980     delaware                2.00                             6.28
# 9  1980      florida                0.00                             0.00
#
#    federal.minimum.wage  federal.minimum.wage.2020.dollars  \
# 0                   3.1                               9.73
# 1                   3.1                               9.73
# 2                   3.1                               9.73
# 3                   3.1                               9.73
# 4                   3.1                               9.73
# 5                   3.1                               9.73
# 6                   3.1                               9.73
# 7                   3.1                               9.73
# 8                   3.1                               9.73
# 9                   3.1                               9.73
#
#    effective.minimum.wage  effective.minimum.wage.2020.dollars  cpi.average  \
# 0                    3.10                                 9.73         82.4
# 1                    3.60                                11.30         82.4
# 2                    3.10                                 9.73         82.4
# 3                    3.10                                 9.73         82.4
# 4                    3.10                                 9.73         82.4
# 5                    3.10                                 9.73         82.4
# 6                    3.12                                 9.79         82.4
# 7                    3.12                                 9.79         82.4
# 8                    3.10                                 9.73         82.4
# 9                    3.10                                 9.73         82.4
#
#   department.of.labor.uncleaned.data  department.of.labor.cleaned.low.value  \
# 0                                ...                                   0.00
# 1                                3.6                                   3.60
# 2                                ...                                   0.00
# 3                               2.55                                   2.55
# 4                                2.9                                   2.90
# 5                                1.9                                   1.90
# 6                               3.12                                   3.12
# 7                               3.12                                   3.12
# 8                                  2                                   2.00
# 9                                ...                                   0.00
#
#    department.of.labor.cleaned.low.value.2020.dollars  \
# 0                                               0.00
# 1                                              11.30
# 2                                               0.00
# 3                                               8.00
# 4                                               9.10
# 5                                               5.96
# 6                                               9.79
# 7                                               9.79
# 8                                               6.28
# 9                                               0.00
#
#    department.of.labor.cleaned.high.value  \
# 0                                    0.00
# 1                                    3.60
# 2                                    0.00
# 3                                    2.55
# 4                                    2.90
# 5                                    1.90
# 6                                    3.12
# 7                                    3.12
# 8                                    2.00
# 9                                    0.00
#
#    department.of.labor.cleaned.high.value.2020.dollars footnote governor
# 0                                               0.00        NaN        D
# 1                                              11.30        NaN        R
# 2                                               0.00        NaN        D
# 3                                               8.00        NaN        D
# 4                                               9.10        NaN        D
# 5                                               5.96        NaN        D
# 6                                               9.79        NaN        D
# 7                                               9.79        NaN        D
# 8                                               6.28        NaN        R
# 9                                               0.00        NaN        D
